# %%
import urllib.request
fileobject = urllib.request.urlopen('https://www.nasdaq.com/')
import requests
BeautifulSoup(requests.get('https://www.nasdaq.com').text, 'html.parser')

# %%
for line in fileobject:
   print(line)
# Out:
# b'<!DOCTYPE html>\n'
# b'<html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">\n'
# b'  <head>\n'
# b'    <meta charset="utf-8" />\n'
# b'<meta itemprop="acquia_lift:content_title" content="Daily Stock Market Overview, Data Updates, Reports &amp; News" />\n'
# b'<meta itemprop="acquia_lift:content_type" content="homepage" />\n'
# b'<meta itemprop="acquia_lift:page_type" content="node page" />\n'
# b'<meta itemprop="acquia_lift:context_language" content="en" />\n'
# b'<meta itemprop="acquia_lift:content_section" content="home" />\n'
# b'<meta itemprop="acquia_lift:content_keywords" content="" />\n'
# ...

# %%
import requests
link = 'https://www.nasdaq.com/market-activity/funds-and-etfs/vfiax'
soup = BeautifulSoup(requests.get(link).text, 'html.parser')

# %%
soup.select('div class="quote-page-chart__chart-container loaded"')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-f00a9a1b024a> in <module>()
# ----> 1 soup.select('div class="quote-page-chart__chart-container loaded"')
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in select(self, selector, _candidate_generator, limit)
#    1475             else:
#    1476                 raise ValueError(
# -> 1477                     'Unsupported or invalid CSS selector: "%s"' % token)
#    1478             if recursive_candidate_generator:
#    1479                 # This happens when the selector looks like  "> foo".
#
# ValueError: Unsupported or invalid CSS selector: "class=quote-page-chart__chart-container loaded"

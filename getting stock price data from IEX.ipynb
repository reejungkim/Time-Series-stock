# %%
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style
import pandas as pd
import pandas_datareader.data as pdr

style.use('ggplot')


#asset_list= ['AAPL', 'NFLX']
#df = pdr.DataReader(asset_list, 'iex', '2019-01-01', '2019-02-01')
df = pdr.DataReader('AAPL', 'iex', '2019-01-01', '2019-02-01')

#df.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-72c9d621a2cf> in <module>()
#       4 from matplotlib import style
#       5 import pandas as pd
# ----> 6 import pandas_datareader.data as pdr
#       7
#       8 style.use('ggplot')
#
# ~\Anaconda3\lib\site-packages\pandas_datareader\__init__.py in <module>()
#       1 from ._version import get_versions
# ----> 2 from .data import (DataReader, Options, get_components_yahoo,
#       3                    get_dailysummary_iex, get_data_enigma, get_data_famafrench,
#       4                    get_data_fred, get_data_google, get_data_moex,
#       5                    get_data_morningstar, get_data_quandl, get_data_stooq,
#
# ~\Anaconda3\lib\site-packages\pandas_datareader\data.py in <module>()
#      12     ImmediateDeprecationError
#      13 from pandas_datareader.famafrench import FamaFrenchReader
# ---> 14 from pandas_datareader.fred import FredReader
#      15 from pandas_datareader.google.daily import GoogleDailyReader
#      16 from pandas_datareader.google.options import Options as GoogleOptions
#
# ~\Anaconda3\lib\site-packages\pandas_datareader\fred.py in <module>()
# ----> 1 from pandas.core.common import is_list_like
#       2 from pandas import concat, read_csv
#       3
#       4 from pandas_datareader.base import _BaseReader
#       5
#
# ImportError: cannot import name 'is_list_like'

# %%
df.head()
# Out:
#               open      high     low   close    volume
# date
# 2019-01-02  154.89  158.8500  154.23  157.92  37039737
# 2019-01-03  143.98  145.7200  142.00  142.19  91312195
# 2019-01-04  144.53  148.5499  143.80  148.26  58607070
# 2019-01-07  148.70  148.8300  145.90  147.93  54777764
# 2019-01-08  149.56  151.8200  148.52  150.75  41025314

# %%
df.describe()
# Out:
#              open        high         low       close        volume
# count   22.000000   22.000000   22.000000   22.000000  2.200000e+01
# mean   154.215455  156.141814  152.583209  154.727727  3.912579e+07
# std      5.781547    5.928436    5.706446    5.840296  1.564867e+07
# min    143.980000  145.720000  142.000000  142.190000  2.313057e+07
# 25%    150.960000  153.467500  149.735000  152.392500  2.996436e+07
# 50%    154.130000  155.510000  152.180000  153.860000  3.364946e+07
# 75%    156.135000  158.067500  154.200000  156.690000  4.144676e+07
# max    166.960000  169.000000  165.930000  166.520000  9.131220e+07

# %%
df.plot()

# %%
g5 = df.plot()
g5.set_ylim(ymin = 140, ymax=170)
# Out:
# (140, 170)

# %%
graph3 = df.plot(y = 'low',title='APPLE lowest price')
graph3.set_xlabel('date')
graph3.set_ylabel('lowest price')
# Out:
# Text(0,0.5,'lowest price')

# %%
#close = df['close']
#graph = close.plot(title='APPLE closing price')
graph = df.plot(y='close', title='APPLE closing price')
graph.set_xlabel('date')
graph.set_ylabel('close price')
# Out:
# Text(0,0.5,'close price')

# %%
opening = df['open']
graph2 = opening.plot(title = "APPLE opening price")
graph2.set_xlabel('date')
graph2.set_ylabel('opening price')
# Out:
# Text(0,0.5,'opening price')

# %%
graph4 = df.plot(y='volume')
graph4.set_xlabel('date')
graph4.set_ylabel('lowest price')
# Out:
# Text(0,0.5,'lowest price')

# %%
df.plot.scatter('open', 'close')
